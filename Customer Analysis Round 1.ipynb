# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv("files_for_lab/csv_files/file1.csv")
file2 = pd.read_csv("files_for_lab/csv_files/file2.csv")
file3 = pd.read_csv("files_for_lab/csv_files/file3.csv")

# %%
display(file1.head())
display(file2.head())
display(file3.head())
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
display(file1.shape)
display(file2.shape)
display(file3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
col = []
for i in range(len(file1.columns)):
    col.append(file1.columns[i].lower())
file1.columns = col

# %%
columns = file1.columns

# %%
columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
col = []
for i in range(len(file2.columns)):
    col.append(file2.columns[i].lower())
file2.columns = col

# %%
file2 = file2[columns]

# %%
col = []
for i in range(len(file3.columns)):
    col.append(file3.columns[i].lower())
file3.columns = col

# %%
columns3 = file3.columns

# %%
columns == columns3
# Out:
# array([ True, False, False,  True, False,  True,  True,  True,  True,
#        False, False])

# %%
file3 = file3.rename(columns={"state": "st"})

# %%
file3 = file3[columns]

# %%
dataset = pd.concat([file1, file2, file3], axis=0)

# %%
display(dataset.shape)
# Out:
# (12074, 11)

# %%
dataset.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
dataset.select_dtypes(["float64"])
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
dataset.select_dtypes(["object"])
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value number of open complaints     policy type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
display(dataset.head())
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
dataset = dataset.drop(["education", "number of open complaints"], axis=1)

# %%
display(dataset)
# Out:
#      customer          st gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                   23406  71941.0
# 7066  PK87824  California      F                 3096.51  21604.0
# 7067  TD14365  California      M                 8163.89      0.0
# 7068  UP19263  California      M                 7524.44  21941.0
# 7069  Y167826  California      M                 2611.84      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
def replace(x):
    if(isinstance(x, str)):
        x = x.replace("%", "")
        x = float(x)*100
    else:
        x=float(x)
    return x

# %%
dataset["customer lifetime value"] = dataset["customer lifetime value"].apply(replace)

# %%
dataset
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+07      0.0
# 2     AI49188      Nevada      F             1.288743e+08  48767.0
# 3     WW63253  California      M             7.645862e+07      0.0
# 4     GA49547  Washington      M             5.363076e+07  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
dataset.dtypes
# Out:
# customer                    object
# st                          object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
dataset.shape
# Out:
# (12074, 9)

# %%
dataset = dataset.drop_duplicates()

# %%
dataset.shape
# Out:
# (9135, 9)

# %%
dataset[dataset["income"] <= 0]
# Out:
#      customer          st gender  customer lifetime value  income  \
# 0     RB50392  Washington    NaN                      NaN     0.0
# 1     QZ44356     Arizona      F             6.979536e+07     0.0
# 3     WW63253  California      M             7.645862e+07     0.0
# 7     CF85061     Arizona      M             7.216100e+07     0.0
# 10    SX51350  California      M             4.738992e+07     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103  California      F             5.678050e+03     0.0
# 7061  RX91025  California      M             1.987226e+04     0.0
# 7062  AC13887  California      M             4.628995e+03     0.0
# 7067  TD14365  California      M             8.163890e+03     0.0
# 7069  Y167826  California      M             2.611837e+03     0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
